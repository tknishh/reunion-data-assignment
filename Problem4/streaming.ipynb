# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession, types

spark = SparkSession.builder.appName('Streaming').getOrCreate()

# %%
df = spark.read.json('2018-2-4.json', multiLine=True)

# %%
df.show()
# Out:
# +--------------------+--------------------+--------------------------+-----------------------------------+--------------------------+--------------------+----------------------+--------------+--------------------+-----------+--------------+---------------------------------+--------------------+-----------+-----------+-----------+----------------------------+-----------------------+------------------------------+---------------------------+---------------------------+------------+--------------------+------------+--------------+---------------+-----------+---------------------------------------+------------------------+--------------------+--------------------+--------------+--------------------+----------------------+--------------------+------------------+--------------------+--------------------+
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- 12 Strong: struct (nullable = true)
#  |    |-- Genre: string (nullable = true)
#  |    |-- Gross: string (nullable = true)
#  |    |-- IMDB Metascore: string (nullable = true)
#  |    |-- Popcorn Score: long (nullable = true)
#  |    |-- Rating: string (nullable = true)
#  |    |-- Tomato Score: long (nullable = true)
#  |-- A Ciambra: struct (nullable = true)
#  |    |-- Genre: string (nullable = true)
#  |    |-- Gross: string (nullable = true)
#  |    |-- IMDB Metascore: string (nullable = true)
#  |    |-- Popcorn Score: string (nullable = true)
#  |    |-- Rating: string (nullable = true)
#  |    |-- Tomato Score: string (nullable = true)
#  |-- All The Money In The World: struct (nullable = true)
#  |    |-- popcornscore: long (nullable = true)
#  |    |-- rating: string (nullable = true)
#  |    |-- tomatoscore: long (nullable = true)
#  |-- Along With The Gods: The Two Worlds: struct (nullable = true)
#  |    |-- popcornscore: long (nullable = true)
# ...

# %%
import os
import findspark
findspark.init()

import pyspark

# Create a Spark session
spark = pyspark.sql.SparkSession.builder.appName('Read JSON from S3').getOrCreate()

# Read the JSON file from S3
df = spark.read.json('2018-2-4.json', multiLine=True)

# Explore the DataFrame
df.show()
# Out:
# +--------------------+--------------------+--------------------------+-----------------------------------+--------------------------+--------------------+----------------------+--------------+--------------------+-----------+--------------+---------------------------------+--------------------+-----------+-----------+-----------+----------------------------+-----------------------+------------------------------+---------------------------+---------------------------+------------+--------------------+------------+--------------+---------------+-----------+---------------------------------------+------------------------+--------------------+--------------------+--------------+--------------------+----------------------+--------------------+------------------+--------------------+--------------------+
# ...
